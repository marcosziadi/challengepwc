# %%
import pandas as pd

# %%
people = pd.read_csv("../data/raw/people.csv")
salary = pd.read_csv("../data/raw/salary.csv")
descriptions = pd.read_csv("../data/raw/descriptions.csv")

# %%
people.head()
# Out:
#    id   Age  Gender Education Level          Job Title  Years of Experience
# 0   0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1   1  28.0  Female        Master's       Data Analyst                  3.0
# 2   2  45.0    Male             PhD     Senior Manager                 15.0
# 3   3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4   4  52.0    Male        Master's           Director                 20.0

# %%
salary.head()
# Out:
#    id    Salary
# 0   0   90000.0
# 1   1   65000.0
# 2   2  150000.0
# 3   3   60000.0
# 4   4  200000.0

# %%
descriptions.head()
# Out:
#    id                                        Description
# 0   0  I am a 32-year-old male working as a Software ...
# 1   1  I am a 28-year-old data analyst with a Master'...
# 2   2  I am a 45-year-old Senior Manager with a PhD a...
# 3   3  I am a 36-year-old female Sales Associate with...
# 4   4  I am a 52-year-old male with over two decades ...

# %%
df = (
    people
    .merge(salary, on="id", how="left")
    .merge(descriptions, on="id", how="left")
)
df.head()
# Out:
#    id   Age  Gender Education Level          Job Title  Years of Experience  \
# 0   0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1   1  28.0  Female        Master's       Data Analyst                  3.0
# 2   2  45.0    Male             PhD     Senior Manager                 15.0
# 3   3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4   4  52.0    Male        Master's           Director                 20.0
#
#      Salary                                        Description
# 0   90000.0  I am a 32-year-old male working as a Software ...
# 1   65000.0  I am a 28-year-old data analyst with a Master'...
# 2  150000.0  I am a 45-year-old Senior Manager with a PhD a...
# 3   60000.0  I am a 36-year-old female Sales Associate with...
# 4  200000.0  I am a 52-year-old male with over two decades ...

# %% [markdown]
# ### Valores nulos

# %%
df.isnull().sum()
# Out:
# id                     0
# Age                    5
# Gender                 5
# Education Level        5
# Job Title              5
# Years of Experience    2
# Salary                 2
# Description            3
# dtype: int64

# %%
df["Description"].fillna("no-description", inplace=True)
# Out:
# C:\Users\Marcos\AppData\Local\Temp\ipykernel_17436\1252560954.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Description"].fillna("no-description", inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#       id   Age  Gender Education Level                         Job Title  \
# 51    51  33.0    Male        Master's                               NaN
# 60    60  51.0  Female        Master's                               NaN
# 139  139  43.0  Female             NaN  Senior Product Marketing Manager
# 172  172   NaN     NaN             NaN                               NaN
# 219  219  40.0     NaN      Bachelor's       Senior Sales Representative
# 221  221   NaN  Female      Bachelor's    Junior Social Media Specialist
# 225  225  40.0     NaN      Bachelor's          Senior Marketing Manager
# 235  235  32.0     NaN      Bachelor's       Junior Sales Representative
# 260  260   NaN     NaN             NaN                               NaN
# 261  261  37.0  Female             NaN          Senior Financial Manager
# 287  287   NaN  Female      Bachelor's          Senior Marketing Analyst
# 315  315   NaN    Male      Bachelor's          Senior Software Engineer
# 332  332  45.0  Female             PhD                               NaN
# 366  366  31.0  Female             NaN          Junior Financial Analyst
#
#      Years of Experience    Salary  \
# 51                   7.0   85000.0
# 60                  23.0  170000.0
# 139                 14.0  120000.0
# 172                  NaN       NaN
# 219                 12.0  100000.0
# 221                  3.0   45000.0
# 225                 11.0  105000.0
# 235                  3.0   45000.0
# 260                  NaN       NaN
# 261                 10.0  120000.0
# 287                  8.0   85000.0
# 315                 13.0  130000.0
# 332                 16.0  160000.0
# 366                  3.0   50000.0
#
#                                            Description
# 51   I am a 33-year-old Business Intelligence Analy...
# 60   I am a 51-year-old female with a Master's degr...
# 139  I am a 43-year-old Senior Product Marketing Ma...
# 172  As an employee, I bring a wealth of diverse ex...
# 219  I am a 40-year-old Senior Sales Representative...
# 221  I am a 31-year-old female currently working as...
# 225  I am a 40-year-old Senior Marketing Manager wi...
# 235  As a 32-year-old Junior Sales Representative w...
# 260  As an employee, I bring a unique blend of skil...
# 261  I am a 37-year-old Senior Financial Manager wi...
# 287  As a 35-year-old Senior Marketing Analyst with...
# 315  I am a Senior Software Engineer with 13 years ...
# 332  I am a 45-year-old Senior UX Designer with a P...
# 366  I am a 31-year-old female working as a Junior ...

# %%
import re
def extract_capital_words(s):
    return " ".join(re.findall(r'\b[A-Z][a-zA-Z]*\b', s))

# 1️⃣ Eliminar primera palabra si empieza con mayúscula
df["cleaned"] = df["Description"].str.replace(r'^[A-Z][a-zA-Z]*\b\s*', '', regex=True)
# 2️⃣ Eliminar palabras después de un punto
df["cleaned"] = df["cleaned"].str.replace(r'\.\s*\b[A-Z][a-zA-Z]*\b', '.', regex=True)

# Extrar palabras con mayuscula
df["capital_words"] = df["cleaned"].apply(extract_capital_words)

df["capital_words"] = df["capital_words"].replace(r"\b(My|I)\b", "", regex=True)
df.head()
# Out:
#    id   Age  Gender Education Level          Job Title  Years of Experience  \
# 0   0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1   1  28.0  Female        Master's       Data Analyst                  3.0
# 2   2  45.0    Male             PhD     Senior Manager                 15.0
# 3   3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4   4  52.0    Male        Master's           Director                 20.0
#
#      Salary                                        Description  \
# 0   90000.0  I am a 32-year-old male working as a Software ...
# 1   65000.0  I am a 28-year-old data analyst with a Master'...
# 2  150000.0  I am a 45-year-old Senior Manager with a PhD a...
# 3   60000.0  I am a 36-year-old female Sales Associate with...
# 4  200000.0  I am a 52-year-old male with over two decades ...
#
#                                              cleaned  \
# 0  am a 32-year-old male working as a Software En...
# 1  am a 28-year-old data analyst with a Master's ...
# 2  am a 45-year-old Senior Manager with a PhD and...
# 3  am a 36-year-old female Sales Associate with a...
# 4  am a 52-year-old male with over two decades of...
#
#                                        capital_words
# 0  Software Engineer Bachelor Computer Science  P...
# 1                                            Master
# 2                               Senior Manager PhD
# 3                           Sales Associate Bachelor
# 4                                   Director Master

# %%
df["capital_words"].to_list()
# Out:
# ['Software Engineer Bachelor Computer Science  Python Java C  Agile DevOps',
#  'Master ',
#  'Senior Manager PhD  ',
#  'Sales Associate Bachelor',
#  'Director Master ',
#  'Marketing Analyst Bachelor',
#  'Master Product Manager',
#  'Sales Manager Bachelor  ',
#  'Marketing Coordinator Bachelor ',
#  'Senior Scientist PhD ',
#  'Software Developer Master Computer Science Java Python JavaScript  ',
#  'HR Manager Bachelor HR',
#  'Financial Analyst Bachelor Finance ',
#  'Master Project Manager',
#  'Customer Service Representative Bachelor  ',
#  'Bachelor Operations Manager',
#  'Marketing Manager Master',
#  'Senior Engineer PhD',
#  'Data Entry Clerk Bachelor  ',
#  'Sales Director Bachelor  ',
#  'Business Analyst Master',
#  'Master Vice President Operations ',
#  'IT Support Specialist Bachelor  IT',
#  'Recruiter Bachelor',
#  'Master Finance Financial Manager',
#  'Social Media Specialist Bachelor',
#  'Master Computer Science Software Manager ',
#  'Junior Developer Bachelor  ',
#  'Senior Consultant PhD PhD ',
#  'Master Design Product Designer',
#  'Bachelor  CEO ',
#  'Bachelor  ',
#  'Data Scientist Master A B ',
#  'Marketing Specialist Bachelor  ',
#  'Senior Manager PhD ',
#  'Technical Writer Bachelor',
#  'HR Generalist Bachelor  HR  HR',
#  'Master Project Engineer  ',
#  'Bachelor Customer Success Representative  ',
#  'Sales Executive Bachelor  ',
#  'UX Designer Master  ',
#  'Master  Operations Director',
#  'Network Engineer Bachelor Computer Science',
#  'Administrative Assistant Bachelor',
#  'Master Strategy Consultant ',
#  'Bachelor',
#  'Account Manager Bachelor  ',
#  'Master Director Marketing  ',
#  'Senior Scientist PhD',
#  'Help Desk Analyst Bachelor IT   ',
#  'Bachelor  Customer Service Manager',
#  'Business Intelligence Analyst Master BI SQL Tableau Power BI',
#  'Bachelor Event Coordinator',
#  'Master Vice President Finance ',
#  'Bachelor',
#  'Sales Manager Bachelor',
#  'UX Researcher Master ',
#  'Senior Engineer PhD ',
#  'Social Media Manager Bachelor',
#  'Master Product Manager ',
#  'Master Director Operations ',
#  'Marketing Analyst Bachelor ',
#  'HR Manager Bachelor Human Resources  HR HR',
#  'Senior Data Scientist PhD  ',
#  'Junior Accountant Bachelor  ',
#  'Master Digital Marketing Digital Marketing Manager  SEO SEM',
#  'IT Manager Bachelor Information Technology IT IT IT  IT',
#  'Customer Service Representative Bachelor ',
#  'Master Business Development Manager  ',
#  'Senior Financial Analyst Master Finance ',
#  'Web Developer Bachelor  HTML CSS JavaScript WordPress Joomla PHP Node MySQL MongoDB ',
#  'Bachelor Recruiter',
#  'PhD Research Director ',
#  'Technical Support Specialist Bachelor ',
#  'Master Creative Director',
#  'Bachelor Project Manager',
#  'Bachelor Operations Manager ',
#  'Senior Software Engineer Master Computer Science ',
#  'Master Human Resources  Human Resources Director HR ',
#  'Content Marketing Manager Bachelor  ',
#  'Technical Recruiter Bachelor ',
#  'Master Data Analyst SQL Python R Excel Tableau Power BI',
#  'Sales Representative Bachelor   ',
#  'PhD  Chief Technology Officer CTO  CTO  IT',
#  'Junior Designer Bachelor  ',
#  'Master Financial Advisor ',
#  'Junior Account Manager Bachelor ',
#  'HR Generalist Bachelor HR',
#  'Senior Project Manager Master ',
#  'Marketing Coordinator Bachelor ',
#  'PhD Principal Scientist ',
#  'Sales Associate Bachelor ',
#  'Bachelor Supply Chain Manager  ',
#  'Senior Marketing Manager Master Marketing ',
#  'Business Analyst Bachelor ',
#  'Bachelor Training Specialist',
#  'PhD Research Scientist   ',
#  'Junior Software Developer Bachelor ',
#  'Public Relations Manager Master PR ',
#  'Operations Analyst Bachelor ',
#  'Event Coordinator Bachelor  ',
#  'Master Product Marketing Manager ',
#  'Senior HR Manager Master Human Resources HR HR HR',
#  'Junior Web Developer Bachelor  ',
#  'Senior Project Coordinator Master',
#  'PhD Data Science Chief Data Officer ',
#  'Bachelor Digital Content Producer',
#  'IT Support Specialist Bachelor  IT',
#  'Senior Marketing Analyst Master  ',
#  'Customer Success Manager Bachelor',
#  'Senior Graphic Designer Master Graphic Design ',
#  '',
#  'Bachelor Supply Chain Analyst',
#  'Senior Business Analyst Master ',
#  'Junior Marketing Analyst Bachelor  ',
#  'Senior Financial Analyst Master Finance ',
#  'Bachelor  Office Manager',
#  'Principal Engineer PhD',
#  'Junior HR Generalist Bachelor HR  HR',
#  'Senior Product Manager Master ',
#  'Bachelor Sales Manager  ',
#  'Master Director Marketing  ',
#  'Junior Operations Analyst Bachelor ',
#  'Customer Service Manager Bachelor',
#  'Senior Scientist PhD',
#  '',
#  'Senior HR Generalist Master  HR HR',
#  'Sales Operations Manager Bachelor',
#  'Marketing Coordinator Bachelor',
#  'Senior Software Developer Master Computer Science Java Python JavaScript Agile Scrum ',
#  'Master Director Operations  ',
#  'Junior Web Designer Bachelor ',
#  'Senior Training Specialist Master   ',
#  'Senior Research Scientist PhD  ',
#  'Junior Sales Representative Bachelor ',
#  'Bachelor Administrative Assistant  ',
#  'Senior Project Manager Master',
#  'Junior Marketing Manager Bachelor ',
#  'Junior Data Analyst Bachelor Computer Science SQL Python Excel Tableau Power BI',
#  'Senior Product Marketing Manager Master',
#  'Junior Business Analyst Bachelor',
#  'Master Marketing Senior Marketing Manager',
#  'Junior Software Developer Bachelor Computer Science ',
#  'Senior Sales Manager Bachelor',
#  'Junior Marketing Specialist Master  ',
#  'Senior Business Analyst Bachelor  ',
#  'Senior Data Scientist PhD Computer Science Python R SQL TensorFlow Hadoop Spark  STEM',
#  'Junior Project Manager Bachelor',
#  'Senior Accountant Bachelor',
#  'Master Business Administration  Director Sales',
#  'Junior Recruiter Bachelor ',
#  'Senior Business Development Manager Master',
#  'Senior Product Designer PhD ',
#  'Junior Customer Support Specialist Bachelor',
#  'Master Marketing Senior Marketing Analyst ',
#  'Senior IT Support Specialist Bachelor Information Technology IT',
#  'Junior Financial Analyst Bachelor  ',
#  'Senior Operations Manager Master ',
#  'PhD Director Human Resources  HR HR HR',
#  'Junior Software Engineer Bachelor Computer Science',
#  'Senior Sales Representative Bachelor ',
#  'Master Director Product Management ',
#  'Junior Copywriter Bachelor ',
#  'Senior Marketing Coordinator Bachelor ',
#  'Senior Human Resources Manager Master HR HR',
#  'Junior Business Development Associate Bachelor  ',
#  'Senior Account Manager Bachelor  ',
#  'PhD Senior Researcher ',
#  'Bachelor Junior HR Coordinator HR  HR',
#  'Senior Software Engineer Master Computer Science',
#  'Master Finance Director Finance   ',
#  'Junior Marketing Coordinator Bachelor  ',
#  ' ',
#  'Senior Project Manager Bachelor',
#  'Junior Data Scientist Master   ',
#  'Senior Operations Analyst Bachelor ',
#  'PhD  Senior Marketing Manager',
#  '',
#  'Senior Human Resources Coordinator Bachelor HR HR ',
#  'Master  Director Operations ',
#  'Junior Sales Representative Bachelor',
#  'Senior Business Analyst Master Business Administration',
#  'PhD Senior UX Designer UX',
#  'Junior Product Manager Bachelor ',
#  'Senior Marketing Specialist Bachelor ',
#  'Senior IT Project Manager  IT Bachelor ',
#  'Senior Financial Analyst Master Finance',
#  'Senior Quality Assurance Analyst Bachelor ',
#  'PhD Director Sales Marketing  ',
#  'Junior Operations Analyst Bachelor  ',
#  'Senior Account Executive Bachelor  ',
#  'Master Business Administration Director Business Development ',
#  'Junior Social Media Manager Bachelor  ',
#  'Bachelor Senior Product Manager   ',
#  'Senior Human Resources Specialist Master HR',
#  'Junior Business Analyst Bachelor ',
#  'Senior Marketing Coordinator Bachelor  ',
#  'Senior Data Analyst PhD Data Science',
#  'Junior Account Manager Bachelor  ',
#  'Master Computer Science Senior Software Developer   ',
#  'Master Director Human Capital ',
#  'Junior Advertising Coordinator Bachelor ',
#  'Senior Sales Manager Bachelor ',
#  'Junior UX Designer Master  UX ',
#  'Senior Accountant Bachelor Accounting  ',
#  'Senior Marketing Director PhD',
#  'Junior HR Generalist Bachelor HR  HR',
#  'Senior Operations Manager Bachelor ',
#  'Master Director Finance ',
#  'Junior Marketing Coordinator Bachelor  ',
#  'Senior IT Consultant Master Information Technology IT',
#  'Senior Product Designer PhD',
#  'Junior Business Development Associate Bachelor ',
#  'Senior Marketing Analyst Bachelor ',
#  'Senior Software Engineer Bachelor Computer Science  ',
#  'Senior Financial Advisor Master Finance',
#  'Senior Project Coordinator Bachelor',
#  'PhD  Director Operations ',
#  'Junior Business Operations Analyst Bachelor  ',
#  'Senior Sales Representative Bachelor ',
#  'Master Director Marketing  ',
#  'Junior Social Media Specialist Bachelor  ',
#  'Senior Product Development Manager Bachelor ',
#  'Senior Human Resources Manager Master  HR HR ',
#  'Junior Financial Analyst Bachelor ',
#  'Senior Marketing Manager Bachelor ',
#  'Senior Data Scientist PhD  ',
#  'Junior Operations Manager Bachelor  ',
#  'Senior Software Architect Master Computer Science ',
#  'Master Human Resources Management  Director Human Resources  HR HR',
#  'Junior Marketing Specialist Bachelor ',
#  'Senior Project Manager Bachelor',
#  'Junior Research Scientist Master ',
#  'Senior Operations Analyst Bachelor ',
#  'Senior Marketing Manager PhD ',
#  'Junior Sales Representative Bachelor ',
#  'Senior Financial Analyst Bachelor Finance ',
#  'Senior Software Developer Master Computer Science  Java Python JavaScript  ',
#  'Junior Operations Analyst Bachelor',
#  'Senior Marketing Specialist Bachelor Marketing  ',
#  'Senior HR Manager PhD HR  HR HR',
#  'Junior Business Analyst Bachelor  ',
#  'Senior Product Manager Bachelor  ',
#  'PhD Senior Data Analyst ',
#  'Junior Marketing Analyst Bachelor ',
#  'Senior Operations Manager Bachelor  ',
#  'Master Marketing  Director Marketing',
#  'Junior Financial Analyst Bachelor',
#  'Senior Project Coordinator Bachelor ',
#  'Master Director Operations  ',
#  'Junior Marketing Coordinator Bachelor',
#  'Senior IT Consultant Master Information Technology IT IT ',
#  'PhD Design Senior Product Designer ',
#  'Junior Business Development Associate Bachelor ',
#  'Senior Marketing Analyst Bachelor ',
#  'Senior Software Engineer Bachelor Computer Science  ',
#  'Senior Financial Advisor Master Finance ',
#  'Senior Project Coordinator Bachelor',
#  'PhD  Director Operations  ',
#  'Junior Business Operations Analyst Bachelor  ',
#  '   ',
#  'Senior Financial Manager Bachelor',
#  'Senior Data Scientist PhD Computer Science ',
#  'Bachelor Junior Marketing Coordinator  ',
#  'Senior Operations Manager Bachelor  ',
#  'Junior Sales Representative Bachelor',
#  'Senior Marketing Specialist Bachelor ',
#  'Senior HR Specialist Master HR HR ',
#  'Junior Operations Manager Bachelor ',
#  'Senior Marketing Coordinator Bachelor ',
#  'Senior Data Engineer PhD Computer Science Python SQL Hadoop Spark  ',
#  'Bachelor Junior Marketing Manager   ',
#  'Senior Financial Analyst Bachelor Finance  ',
#  'Master Director Marketing ',
#  'Junior Business Analyst Bachelor ',
#  'Senior Project Manager Bachelor',
#  'Senior Data Analyst PhD',
#  'Junior Financial Analyst Bachelor  ',
#  'Bachelor Senior Product Manager ',
#  'Master Business Administration Director Operations ',
#  'Junior Operations Analyst Bachelor ',
#  'Senior Project Coordinator Bachelor',
#  'Master Marketing Director Marketing ',
#  'Junior Business Development Associate Bachelor ',
#  'Senior Financial Manager Bachelor ',
#  'Senior Product Designer PhD',
#  'Junior Business Analyst Bachelor',
#  'Senior Marketing Analyst Bachelor   ',
#  'Senior Software Engineer Bachelor Computer Science ',
#  'Junior Product Manager Bachelor ',
#  'Senior Business Analyst Bachelor ',
#  'PhD  Director Operations',
#  'Junior Marketing Specialist Bachelor ',
#  'Senior Business Development Manager Bachelor Business Administration ',
#  'Master Human Resources Management Senior HR Manager  HR HR HR',
#  'Junior Financial Analyst Bachelor ',
#  'Senior Marketing Manager Bachelor  ',
#  'Senior Data Scientist PhD Computer Science ',
#  'Junior Operations Coordinator Bachelor ',
#  'Senior Marketing Analyst Bachelor ',
#  'Master Director Human Resources HR  HR ',
#  'Junior Project Manager Bachelor',
#  'Senior Operations Coordinator Bachelor',
#  'Senior Data Engineer PhD Computer Science',
#  'Junior Marketing Manager Bachelor  ',
#  'Senior Business Analyst Bachelor ',
#  'Master Marketing  Director Marketing ',
#  'Junior Operations Analyst Bachelor  ',
#  'Senior Project Manager Bachelor ',
#  'Master Marketing Director Marketing ',
#  'Junior Business Development Associate Bachelor ',
#  'Senior Financial Manager Bachelor Finance',
#  'Senior Product Designer PhD ',
#  'Junior Business Analyst Bachelor  ',
#  'Senior Marketing Analyst Bachelor  ',
#  'Senior Software Engineer Bachelor ',
#  'Senior Financial Advisor Master Finance  ',
#  'Senior Marketing Specialist Bachelor ',
#  'Junior HR Coordinator Bachelor HR HR',
#  'Senior Business Development Manager Bachelor ',
#  'Senior Marketing Manager Master Marketing  ',
#  'Junior Financial Advisor Bachelor',
#  'Senior Project Manager Bachelor  ',
#  'PhD Director Engineering  ',
#  'Junior Marketing Analyst Bachelor   ',
#  'Senior Operations Manager Bachelor',
#  'PhD Senior Data Scientist  ',
#  'Junior Marketing Coordinator Bachelor  ',
#  'Senior Business Analyst Bachelor ',
#  'Master Director Marketing  ',
#  'Junior Business Development Associate Bachelor ',
#  'Senior Financial Analyst Bachelor ',
#  'Senior UX Designer PhD ',
#  'Junior Product Manager Bachelor',
#  'Senior Marketing Manager Bachelor',
#  'Master Director Operations ',
#  'Junior Project Manager Bachelor ',
#  'Senior Operations Coordinator Bachelor ',
#  'PhD Senior Business Analyst',
#  'Bachelor Junior Marketing Specialist ',
#  'Senior Financial Manager Bachelor  ',
#  'Master Director Marketing   ',
#  'Junior Financial Analyst Bachelor  ',
#  'Senior Product Manager Bachelor',
#  'Senior Data Engineer PhD ',
#  'Junior Business Analyst Bachelor',
#  'Senior Marketing Analyst Bachelor ',
#  'Master Director Engineering',
#  'Junior Operations Manager Bachelor ',
#  'Senior Business Development Manager Bachelor ',
#  'PhD Senior Data Scientist  ',
#  'Junior Marketing Coordinator Bachelor ',
#  'Senior Business Analyst Bachelor ',
#  'Master Marketing  Director Marketing ',
#  'Junior Business Development Associate Bachelor ',
#  'Senior Financial Analyst Bachelor',
#  'Senior UX Designer PhD  ',
#  'Junior Product Manager Bachelor ',
#  'Senior Marketing Manager Bachelor',
#  'Master Director Operations ',
#  'Junior Project Manager Bachelor ',
#  'Senior Operations Coordinator Bachelor ',
#  'Senior Business Analyst PhD',
#  'Bachelor Junior Marketing Specialist ',
#  'Senior Financial Manager Bachelor ',
#  'Master Director Marketing  ',
#  'Junior Financial Analyst Bachelor ',
#  'Senior Product Manager Bachelor ',
#  'PhD Computer Science Senior Data Engineer',
#  'Junior Business Analyst Bachelor',
#  'Senior Marketing Analyst Bachelor ',
#  'Master Business Administration Director Operations  ',
#  'Junior Project Manager Bachelor  ',
#  'Senior Operations Coordinator Bachelor ',
#  'Senior Business Analyst PhD ']

# %%
df["Age_New"] = df["Description"].str.extract(r'(\d+)(?:-?year-old| years old)')[0].astype(float)
df["Age_New"] = df["Age_New"].fillna(df["Age"])
df.isnull().sum()
# Out:
# id                     0
# Age                    5
# Gender                 5
# Education Level        5
# Job Title              5
# Years of Experience    2
# Salary                 2
# Description            0
# cleaned                0
# capital_words          0
# Age_New                3
# dtype: int64

# %%
df.head()
# Out:
#    id   Age  Gender Education Level          Job Title  Years of Experience  \
# 0   0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1   1  28.0  Female        Master's       Data Analyst                  3.0
# 2   2  45.0    Male             PhD     Senior Manager                 15.0
# 3   3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4   4  52.0    Male        Master's           Director                 20.0
#
#      Salary                                        Description  \
# 0   90000.0  I am a 32-year-old male working as a Software ...
# 1   65000.0  I am a 28-year-old data analyst with a Master'...
# 2  150000.0  I am a 45-year-old Senior Manager with a PhD a...
# 3   60000.0  I am a 36-year-old female Sales Associate with...
# 4  200000.0  I am a 52-year-old male with over two decades ...
#
#                                              cleaned  \
# 0  am a 32-year-old male working as a Software En...
# 1  am a 28-year-old data analyst with a Master's ...
# 2  am a 45-year-old Senior Manager with a PhD and...
# 3  am a 36-year-old female Sales Associate with a...
# 4  am a 52-year-old male with over two decades of...
#
#                                        capital_words  Age_New
# 0  Software Engineer Bachelor Computer Science  P...     32.0
# 1                                            Master      28.0
# 2                               Senior Manager PhD       45.0
# 3                           Sales Associate Bachelor     36.0
# 4                                   Director Master      52.0

# %%
list(df["Education Level"].unique())[:-1]
# Out:
# ["Bachelor's", "Master's", 'PhD']

# %%
# df[df["Gender"].isnull()]
df[df["Education Level"].isnull()]
# Out:
#       id   Age  Gender Education Level                         Job Title  \
# 139  139  43.0  Female             NaN  Senior Product Marketing Manager
# 172  172   NaN     NaN             NaN                               NaN
# 260  260   NaN     NaN             NaN                               NaN
# 261  261  37.0  Female             NaN          Senior Financial Manager
# 366  366  31.0  Female             NaN          Junior Financial Analyst
#
#      Years of Experience    Salary  \
# 139                 14.0  120000.0
# 172                  NaN       NaN
# 260                  NaN       NaN
# 261                 10.0  120000.0
# 366                  3.0   50000.0
#
#                                            Description  \
# 139  I am a 43-year-old Senior Product Marketing Ma...
# 172  As an employee, I bring a wealth of diverse ex...
# 260  As an employee, I bring a unique blend of skil...
# 261  I am a 37-year-old Senior Financial Manager wi...
# 366  I am a 31-year-old female working as a Junior ...
#
#                                                cleaned  \
# 139  am a 43-year-old Senior Product Marketing Mana...
# 172  an employee, I bring a wealth of diverse exper...
# 260  an employee, I bring a unique blend of skills ...
# 261  am a 37-year-old Senior Financial Manager with...
# 366  am a 31-year-old female working as a Junior Fi...
#
#                                capital_words  Age_New
# 139  Senior Product Marketing Manager Master     43.0
# 172                                               NaN
# 260                                               NaN
# 261        Senior Financial Manager Bachelor     37.0
# 366       Junior Financial Analyst Bachelor      31.0

# %%
levels = ["Bachelor's", "Master's", "PhD"]

# Crear un patrón regex a partir de la lista
pattern = r'(' + '|'.join(map(re.escape, levels)) + r')'

# Buscar y asignar el valor encontrado
df["New_Education_Level"] = df["Description"].str.extract(pattern, expand=False)
df["New_Education_Level"] = df["New_Education_Level"].fillna(df["Education Level"])
df.isnull().sum()
# Out:
# id                     0
# Age                    5
# Gender                 5
# Education Level        5
# Job Title              5
# Years of Experience    2
# Salary                 2
# Description            0
# cleaned                0
# capital_words          0
# Age_New                3
# New_Education_Level    2
# dtype: int64

# %%
# df[df["Job Title"].isnull()]
# # df.loc[60, "capital_words"]
levels = r"(Bachelor|Master|PhD)"

def split_job_edu(s):
    match = re.search(levels, s)
    if not match:
        return None, None  # sin educación → todo es Job_Title
    
    edu = match.group(1)
    start, end = match.span()
    
    # Si el nivel educativo está al inicio
    if start == 0:
        job = s[end:].strip()
    else:
        job = s[:start].strip()
    
    return edu, job

df[["New_Education_Level", "New_Job_Title"]] = df["capital_words"].apply(
    lambda x: pd.Series(split_job_edu(x))
)
df.head()
# Out:
#    id   Age  Gender Education Level          Job Title  Years of Experience  \
# 0   0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1   1  28.0  Female        Master's       Data Analyst                  3.0
# 2   2  45.0    Male             PhD     Senior Manager                 15.0
# 3   3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4   4  52.0    Male        Master's           Director                 20.0
#
#      Salary                                        Description  \
# 0   90000.0  I am a 32-year-old male working as a Software ...
# 1   65000.0  I am a 28-year-old data analyst with a Master'...
# 2  150000.0  I am a 45-year-old Senior Manager with a PhD a...
# 3   60000.0  I am a 36-year-old female Sales Associate with...
# 4  200000.0  I am a 52-year-old male with over two decades ...
#
#                                              cleaned  \
# 0  am a 32-year-old male working as a Software En...
# 1  am a 28-year-old data analyst with a Master's ...
# 2  am a 45-year-old Senior Manager with a PhD and...
# 3  am a 36-year-old female Sales Associate with a...
# 4  am a 52-year-old male with over two decades of...
#
#                                        capital_words  Age_New  \
# 0  Software Engineer Bachelor Computer Science  P...     32.0
# 1                                            Master      28.0
# 2                               Senior Manager PhD       45.0
# 3                           Sales Associate Bachelor     36.0
# 4                                   Director Master      52.0
#
#   New_Education_Level      New_Job_Title
# 0            Bachelor  Software Engineer
# 1              Master
# 2                 PhD     Senior Manager
# 3            Bachelor    Sales Associate
# 4              Master           Director

# %%
df.iloc[[51, 60, 172, 260, 332]]
# Out:
#       id   Age  Gender Education Level Job Title  Years of Experience  \
# 51    51  33.0    Male        Master's       NaN                  7.0
# 60    60  51.0  Female        Master's       NaN                 23.0
# 172  172   NaN     NaN             NaN       NaN                  NaN
# 260  260   NaN     NaN             NaN       NaN                  NaN
# 332  332  45.0  Female             PhD       NaN                 16.0
#
#        Salary                                        Description  \
# 51    85000.0  I am a 33-year-old Business Intelligence Analy...
# 60   170000.0  I am a 51-year-old female with a Master's degr...
# 172       NaN  As an employee, I bring a wealth of diverse ex...
# 260       NaN  As an employee, I bring a unique blend of skil...
# 332  160000.0  I am a 45-year-old Senior UX Designer with a P...
#
#                                                cleaned  \
# 51   am a 33-year-old Business Intelligence Analyst...
# 60   am a 51-year-old female with a Master's degree...
# 172  an employee, I bring a wealth of diverse exper...
# 260  an employee, I bring a unique blend of skills ...
# 332  am a 45-year-old Senior UX Designer with a PhD...
#
#                                          capital_words  Age_New  \
# 51   Business Intelligence Analyst Master BI SQL Ta...     33.0
# 60                         Master Director Operations      51.0
# 172                                                         NaN
# 260                                                         NaN
# 332                            Senior UX Designer PhD      45.0
#
#     New_Education_Level                  New_Job_Title
# 51               Master  Business Intelligence Analyst
# 60               Master            Director Operations
# 172                None                           None
# 260                None                           None
# 332                 PhD             Senior UX Designer

# %%
import numpy as np

df["New_Job_Title"] = np.where(
    df["Job Title"].notna(),
    df["Job Title"],   # si difiere, lo dejamos
    df["New_Job_Title"]        # si es igual o NaN → usamos Job Title
)
df
# Out:
#       id   Age  Gender Education Level                      Job Title  \
# 0      0  32.0    Male      Bachelor's              Software Engineer
# 1      1  28.0  Female        Master's                   Data Analyst
# 2      2  45.0    Male             PhD                 Senior Manager
# 3      3  36.0  Female      Bachelor's                Sales Associate
# 4      4  52.0    Male        Master's                       Director
# ..   ...   ...     ...             ...                            ...
# 370  370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  371  43.0    Male        Master's         Director of Operations
# 372  372  29.0  Female      Bachelor's         Junior Project Manager
# 373  373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary  \
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
#                                            Description  \
# 0    I am a 32-year-old male working as a Software ...
# 1    I am a 28-year-old data analyst with a Master'...
# 2    I am a 45-year-old Senior Manager with a PhD a...
# 3    I am a 36-year-old female Sales Associate with...
# 4    I am a 52-year-old male with over two decades ...
# ..                                                 ...
# 370  As a 35-year-old Senior Marketing Analyst with...
# 371  I am a 43-year-old male with a Master's degree...
# 372  As a 29-year-old female Junior Project Manager...
# 373  As a Senior Operations Coordinator with a Bach...
# 374  I am a 44-year-old Senior Business Analyst wit...
#
#                                                cleaned  \
# 0    am a 32-year-old male working as a Software En...
# 1    am a 28-year-old data analyst with a Master's ...
# 2    am a 45-year-old Senior Manager with a PhD and...
# 3    am a 36-year-old female Sales Associate with a...
# 4    am a 52-year-old male with over two decades of...
# ..                                                 ...
# 370  a 35-year-old Senior Marketing Analyst with a ...
# 371  am a 43-year-old male with a Master's degree i...
# 372  a 29-year-old female Junior Project Manager wi...
# 373  a Senior Operations Coordinator with a Bachelo...
# 374  am a 44-year-old Senior Business Analyst with ...
#
#                                          capital_words  Age_New  \
# 0    Software Engineer Bachelor Computer Science  P...     32.0
# 1                                              Master      28.0
# 2                                 Senior Manager PhD       45.0
# 3                             Sales Associate Bachelor     36.0
# 4                                     Director Master      52.0
# ..                                                 ...      ...
# 370                 Senior Marketing Analyst Bachelor      35.0
# 371  Master Business Administration Director Operat...     43.0
# 372                  Junior Project Manager Bachelor       29.0
# 373            Senior Operations Coordinator Bachelor      34.0
# 374                       Senior Business Analyst PhD      44.0
#
#     New_Education_Level                  New_Job_Title
# 0              Bachelor              Software Engineer
# 1                Master                   Data Analyst
# 2                   PhD                 Senior Manager
# 3              Bachelor                Sales Associate
# 4                Master                       Director
# ..                  ...                            ...
# 370            Bachelor       Senior Marketing Analyst
# 371              Master         Director of Operations
# 372            Bachelor         Junior Project Manager
# 373            Bachelor  Senior Operations Coordinator
# 374                 PhD        Senior Business Analyst
#
# [375 rows x 13 columns]

# %%
df[df["New_Job_Title"] != df["Job Title"]]
# Out:
#       id   Age  Gender Education Level Job Title  Years of Experience  \
# 51    51  33.0    Male        Master's       NaN                  7.0
# 60    60  51.0  Female        Master's       NaN                 23.0
# 172  172   NaN     NaN             NaN       NaN                  NaN
# 260  260   NaN     NaN             NaN       NaN                  NaN
# 332  332  45.0  Female             PhD       NaN                 16.0
#
#        Salary                                        Description  \
# 51    85000.0  I am a 33-year-old Business Intelligence Analy...
# 60   170000.0  I am a 51-year-old female with a Master's degr...
# 172       NaN  As an employee, I bring a wealth of diverse ex...
# 260       NaN  As an employee, I bring a unique blend of skil...
# 332  160000.0  I am a 45-year-old Senior UX Designer with a P...
#
#                                                cleaned  \
# 51   am a 33-year-old Business Intelligence Analyst...
# 60   am a 51-year-old female with a Master's degree...
# 172  an employee, I bring a wealth of diverse exper...
# 260  an employee, I bring a unique blend of skills ...
# 332  am a 45-year-old Senior UX Designer with a PhD...
#
#                                          capital_words  Age_New  \
# 51   Business Intelligence Analyst Master BI SQL Ta...     33.0
# 60                         Master Director Operations      51.0
# 172                                                         NaN
# 260                                                         NaN
# 332                            Senior UX Designer PhD      45.0
#
#     New_Education_Level                  New_Job_Title
# 51               Master  Business Intelligence Analyst
# 60               Master            Director Operations
# 172                None
# 260                None
# 332                 PhD             Senior UX Designer
